# %%
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np 

import seaborn as sns

# %matplotlib inline

# %%
sns.set_style('darkgrid')

# %%
df = pd.read_csv('world_population.csv')

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0        41128771.00      38972230.00      33753499.00      28189672.00
# 1         2842321.00       2866849.00       2882481.00       2913399.00
# ...

# %%
# we can display the data with two decimal places

# %%
pd.set_option('display.float_format',lambda x: '%.2f' % x)

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0        41128771.00      38972230.00      33753499.00      28189672.00
# 1         2842321.00       2866849.00       2882481.00       2913399.00
# ...

# %%
# we can have an overview of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              230 non-null    float64
#  6   2020 Population              233 non-null    float64
#  7   2015 Population              230 non-null    float64
#  8   2010 Population              227 non-null    float64
#  9   2000 Population              227 non-null    float64
#  10  1990 Population              229 non-null    float64
#  11  1980 Population              229 non-null    float64
# ...

# %%
# we then look at the overview of the numeric columns

# %%
df.describe()
# Out:
#         Rank  2022 Population  2020 Population  2015 Population  \
# count 234.00           230.00           233.00           230.00
# mean  117.50      34632250.88      33600710.95      32066004.16
# std    67.69     137889172.44     135873196.61     131507146.34
# min     1.00           510.00           520.00           564.00
# 25%    59.25        419738.50        406471.00        394295.00
# 50%   117.50       5762857.00       5456681.00       5244415.00
# 75%   175.75      22653719.00      21522626.00      19730853.75
# max   234.00    1425887337.00    1424929781.00    1393715448.00
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count           227.00           227.00           229.00           229.00
# mean       30270164.48      26840495.26      19330463.93      16282884.78
# std       126074183.54     113352454.57      81309624.96      69345465.54
# min             596.00           651.00           700.00           733.00
# ...

# %%
# we then look at the number of null values in the dataset

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64

# %%
# we can then decide to clean the null values by either filling them or dropping them 

# however that will depend on the number of null values present

# %%
# we can a aslo look at the number of unique values in the dataset

# %%
df.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                        6
# 2022 Population                230
# 2020 Population                233
# 2015 Population                230
# 2010 Population                227
# 2000 Population                227
# 1990 Population                229
# 1980 Population                229
# 1970 Population                230
# Area (km²)                     231
# Density (per km²)              230
# Growth Rate                    178
# World Population Percentage     70
# dtype: int64

# %%
# we can then look at the to tep most populated countries

# %%
df.sort_values(by="2022 Population",ascending=False).head(10)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41     1425887337.00    1424929781.00    1393715448.00    1348191368.00
# 92     1417173173.00    1396387127.00    1322866505.00    1240613620.00
# ...

# %%
# we can look at the corrlation in the data set

# %%
df.corr()
# Out:
#                              Rank  2022 Population  2020 Population  \
# Rank                         1.00            -0.36            -0.36
# 2022 Population             -0.36             1.00             1.00
# 2020 Population             -0.36             1.00             1.00
# 2015 Population             -0.35             1.00             1.00
# 2010 Population             -0.35             1.00             1.00
# 2000 Population             -0.34             0.99             1.00
# 1990 Population             -0.33             0.99             0.99
# 1980 Population             -0.33             0.99             0.99
# 1970 Population             -0.34             0.97             0.98
# Area (km²)                  -0.38             0.45             0.45
# Density (per km²)            0.13            -0.03            -0.03
# Growth Rate                 -0.22            -0.02            -0.03
# World Population Percentage -0.36             1.00             1.00
#
# ...

# %%
# we can see that most of these  values are positively correlated 

# however it would be a lot easier to visualize these correlations

# %%
plt.figure(figsize=(12,8))

sns.heatmap(df.corr(),annot=True);

# %%
# we can then group the dataset by continent and see the difference in population partterns

# %%
df.groupby('Continent').mean().sort_values(by="2020 Population", ascending = False)
# Out:
#                 Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Asia           77.56      96327387.31      94955134.37      89165003.64
# South America  97.57      31201186.29      30823574.50      29509599.71
# Africa         92.16      25455879.68      23871435.26      21419703.57
# Europe        124.50      15055371.82      14915843.92      15027454.12
# North America 160.93      15007403.40      14855914.82      14259596.25
# Oceania       188.52       2046386.32       1910148.96       1756664.48
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Asia               89087770.00      80580835.11      48639995.33
# South America      26789395.54      25015888.69      21224743.93
# Africa             18898197.31      14598365.95      11376964.52
# Europe             14712278.68      14817685.71      14785203.94
# North America      13568016.28      12151739.60      10531660.62
# ...

# %%
# since are interested on how population changes in the  continent we can transpose the data

# we also edit how the data appears so that start from the earliest years to the latest years

# %%
df2 = df.groupby('Continent')[['1970 Population',
       '1980 Population', '1990 Population', '2000 Population',
       '2010 Population', '2015 Population', '2020 Population',
       '2022 Population']].mean().sort_values(by="2020 Population", ascending = False)

# %%
df2
# Out:
#                1970 Population  1980 Population  1990 Population  \
# Continent
# Asia               43839877.83      40278333.33      48639995.33
# South America      13781939.71      17270643.29      21224743.93
# Africa              6567175.27       8586031.98      11376964.52
# Europe             13118479.82      14200004.52      14785203.94
# North America       7885865.15       9207334.03      10531660.62
# Oceania              846968.26        996532.17       1162774.87
#
#                2000 Population  2010 Population  2015 Population  \
# Continent
# Asia               80580835.11      89087770.00      89165003.64
# South America      25015888.69      26789395.54      29509599.71
# Africa             14598365.95      18898197.31      21419703.57
# Europe             14817685.71      14712278.68      15027454.12
# North America      12151739.60      13568016.28      14259596.25
# Oceania             1357512.09       1613163.65       1756664.48
#
# ...

# %%
df3= df2.transpose()

# %%
df3.plot(figsize=(15,8));

# %%
# we are only interested in the population information so we can take the population information from the data set

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country', 'Capital', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (km²)', 'Density (per km²)', 'Growth Rate',
#        'World Population Percentage'],
#       dtype='object')

# %%
# we can select the data types from that dataset

# %%
df.select_dtypes(include='object')
# Out:
#     CCA3            Country           Capital Continent
# 0    AFG        Afghanistan             Kabul      Asia
# 1    ALB            Albania            Tirana    Europe
# 2    DZA            Algeria           Algiers    Africa
# 3    ASM     American Samoa         Pago Pago   Oceania
# 4    AND            Andorra  Andorra la Vella    Europe
# ..   ...                ...               ...       ...
# 229  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230  ESH     Western Sahara          El Aaiún    Africa
# 231  YEM              Yemen             Sanaa      Asia
# 232  ZMB             Zambia            Lusaka    Africa
# 233  ZWE           Zimbabwe            Harare    Africa
#
# [234 rows x 4 columns]

# %%
# the continent looks interesting to look at 

# this is the most unknown continet

# %%
df[df['Continent'].str.contains('Oceania')].sort_values(by='2022 Population',ascending=False).head(10)

# this gives us the most populated countries in the oceania continent
# Out:
#      Rank CCA3           Country       Capital Continent  2022 Population  \
# 11     55  AUS         Australia      Canberra   Oceania      26177413.00
# 160    93  PNG  Papua New Guinea  Port Moresby   Oceania      10142619.00
# 146   123  NZL       New Zealand    Wellington   Oceania       5185288.00
# 66    162  FJI              Fiji          Suva   Oceania        929766.00
# 191   166  SLB   Solomon Islands       Honiara   Oceania        724273.00
# 225   181  VUT           Vanuatu     Port-Vila   Oceania        326740.00
# 70    183  PYF  French Polynesia       Papeete   Oceania        306279.00
# 145   185  NCL     New Caledonia        Nouméa   Oceania        289950.00
# 179   188  WSM             Samoa          Apia   Oceania        222382.00
# 81    191  GUM              Guam       Hagåtña   Oceania        171774.00
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 11       25670051.00      23820236.00      22019168.00      19017963.00
# ...

# %%
# we can look at te mean population by continent

# %%
df_continent=df.groupby('Continent')['2022 Population'].mean().sort_values(ascending =False)

# %%
df_continent
# Out:
# Continent
# Asia            96327387.31
# South America   31201186.29
# Africa          25455879.68
# Europe          15055371.82
# North America   15007403.40
# Oceania          2046386.32
# Name: 2022 Population, dtype: float64

# %%
# we then visualize the continent population 

colors = ['red', 'green', 'blue', 'orange','violet','purple']
df_continent.plot(kind='bar',color=colors);

# %%
# we can also look at the countries with the highest population and there continents

# %%
df[['Country','Continent','2022 Population']].sort_values(by='2022 Population', ascending= False).head(10)
# Out:
#            Country      Continent  2022 Population
# 41           China           Asia    1425887337.00
# 92           India           Asia    1417173173.00
# 221  United States  North America     338289857.00
# 93       Indonesia           Asia     275501339.00
# 156       Pakistan           Asia     235824862.00
# 149        Nigeria         Africa     218541212.00
# 27          Brazil  South America     215313498.00
# 16      Bangladesh           Asia     171186372.00
# 171         Russia         Europe     144713314.00
# 131         Mexico  North America     127504125.00

# %%
# we can also lool at the least populated countries in 2022

# %%
df[['Country','Continent','2022 Population']].sort_values(by='2022 Population', ascending= False).tail(10)
# Out:
#                        Country      Continent  2022 Population
# 177  Saint Pierre and Miquelon  North America          5862.00
# 137                 Montserrat  North America          4390.00
# 64            Falkland Islands  South America          3780.00
# 150                       Niue        Oceania          1934.00
# 209                    Tokelau        Oceania          1871.00
# 226               Vatican City         Europe           510.00
# 62                    Eswatini         Africa              NaN
# 154                     Norway         Europe              NaN
# 157                      Palau        Oceania              NaN
# 207                Timor-Leste           Asia              NaN

# %%
df.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia      41128771.00
# 1   138  ALB         Albania            Tirana    Europe       2842321.00
# 2    34  DZA         Algeria           Algiers    Africa      44903225.00
# 3   213  ASM  American Samoa         Pago Pago   Oceania         44273.00
# 4   203  AND         Andorra  Andorra la Vella    Europe         79824.00
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0      38972230.00      33753499.00      28189672.00      19542982.00
# 1       2866849.00       2882481.00       2913399.00       3182021.00
# 2      43451666.00      39543154.00      35856344.00      30774621.00
# 3         46189.00         51368.00         54849.00         58230.00
# 4         77700.00         71746.00         71519.00         66097.00
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
# we can look at the cities with the highest population

# %%
df[['Capital','Country','2022 Population']].sort_values(by='2022 Population',ascending=False).head(10)
# Out:
#               Capital        Country  2022 Population
# 41            Beijing          China    1425887337.00
# 92          New Delhi          India    1417173173.00
# 221  Washington, D.C.  United States     338289857.00
# 93            Jakarta      Indonesia     275501339.00
# 156         Islamabad       Pakistan     235824862.00
# 149             Abuja        Nigeria     218541212.00
# 27           Brasilia         Brazil     215313498.00
# 16              Dhaka     Bangladesh     171186372.00
# 171            Moscow         Russia     144713314.00
# 131       Mexico City         Mexico     127504125.00

# %%
# we can also look at the cities with the lowest population

# %%
df[['Capital','Country','2022 Population']].sort_values(by='2022 Population',ascending=False).tail(10)
# Out:
#           Capital                    Country  2022 Population
# 177  Saint-Pierre  Saint Pierre and Miquelon          5862.00
# 137        Brades                 Montserrat          4390.00
# 64        Stanley           Falkland Islands          3780.00
# 150         Alofi                       Niue          1934.00
# 209      Nukunonu                    Tokelau          1871.00
# 226  Vatican City               Vatican City           510.00
# 62        Mbabane                   Eswatini              NaN
# 154          Oslo                     Norway              NaN
# 157     Ngerulmud                      Palau              NaN
# 207          Dili                Timor-Leste              NaN

# %%
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia      41128771.00
# 1   138  ALB         Albania            Tirana    Europe       2842321.00
# 2    34  DZA         Algeria           Algiers    Africa      44903225.00
# 3   213  ASM  American Samoa         Pago Pago   Oceania         44273.00
# 4   203  AND         Andorra  Andorra la Vella    Europe         79824.00
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0      38972230.00      33753499.00      28189672.00      19542982.00
# 1       2866849.00       2882481.00       2913399.00       3182021.00
# 2      43451666.00      39543154.00      35856344.00      30774621.00
# 3         46189.00         51368.00         54849.00         58230.00
# 4         77700.00         71746.00         71519.00         66097.00
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...
